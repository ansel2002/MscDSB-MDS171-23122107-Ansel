# %%
class stack:
    def __init__(self):
        self.stack=[]
        




    def push(self,item1):

        self.stack.append(item1)
    

    def pop(self,item1):
              print("popped",self.stack.pop())



    def view(self):
            print(self.stack)


    def size(self):
        print("the size of the stack is ",len(self.stack))   



    def top(self):
         print(self.stack[-1])    


    def empty(self):
        if len(self.stack)==0:
             print("empty stack")

        else:
             print("stack is not empty")     
          


a1 = stack()

# a1.push(10)
# a1.push(12)
# a1.push(13)
# a1.pop()
# a1.view()


# a1.size()
# a1.empty()
# a1.top()

while True:
     print("1. push the stack")
     print("2. pop from the stack ")
     print("3. view the stack")
     print("4. size of the stack")
     print("5. top element of the stack")
     print("6. check if stack is empty or not")
     print("7. Exit")

     choice = int(input("Enter your choice: ").strip())


     if choice == 1:
          a=int(input('enter number to be pushed in stack'))
          a1.push(a)
          
     elif choice == 2:
          a1.pop()  
          
     elif choice == 3:
          a1.view()        
          
     elif choice == 4:
          a1.empty()
          
     elif choice == 5:
          a1.top()
          
     elif choice == 6: 
          a1.empty()  
          
     elif choice == 7: 
          exit()
     else:
        print("in valid choice")
# Out:
# 1. push the stack
# 2. pop from the stack
# 3. view the stack
# 4. size of the stack
# 5. top element of the stack
# 6. check if stack is empty or not
# 7. Exit
# 1. push the stack
# 2. pop from the stack
# 3. view the stack
# 4. size of the stack
# 5. top element of the stack
# 6. check if stack is empty or not
# 7. Exit
# [5]
# 1. push the stack
# 2. pop from the stack
# 3. view the stack
# 4. size of the stack
# 5. top element of the stack
# 6. check if stack is empty or not
# 7. Exit
# 1. push the stack
# 2. pop from the stack
# 3. view the stack
# 4. size of the stack
# 5. top element of the stack
# 6. check if stack is empty or not
# 7. Exit
# [5, 8]
# 1. push the stack
# 2. pop from the stack
# 3. view the stack
# 4. size of the stack
# 5. top element of the stack
# 6. check if stack is empty or not
# 7. Exit
# [5, 8]
# 1. push the stack
# 2. pop from the stack
# 3. view the stack
# 4. size of the stack
# 5. top element of the stack
# 6. check if stack is empty or not
# ...
